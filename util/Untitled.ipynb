# %%
from ipywidgets import IntSlider
IntSlider()
# Out:
# IntSlider(value=0)

# %%
from collections import Counter

# %%
a = Counter("helelo")
print(a)
# Out:
# Counter({'e': 2, 'l': 2, 'h': 1, 'o': 1})
